# %% [markdown]
# # Fifth Session, Notebook # 11: Introduction to AstroQuery
#
# ## Today's agenda:
# 0. __Workshop Overview__:
#     * __When__: August 16th  1pm-5pm
#     * __Where__: American Museum of Natural History, Perkin Reading Room, located on the 5th floor of the Rose Center.
#     * __What__: Today we will be practicing with AstroQuery!
#     * __Want__ to lead a session for a topic? Some Days there will be small hack sessions for people to discuss problems they're working on.
#     * __Online Resources__:  __https://daxfeliz.github.io/cunybridgebootcamp/__
#     * __Program Schedule__: __https://tinyurl.com/mu88x9xc__
# &nbsp;
#
# 1. __This session__:
# * Useful functions of [AstroQuery](https://astroquery.readthedocs.io/en/latest/)
# * Grabbing published data tables
# * Querying online data bases
# * Looking up published measurements of individual stars
# * cross matching catalogs
# *
# </br>
# &nbsp;
#
# 2. __Next session__:
#     * Open Hack Session and Introduction to LaTeX! __Make sure you bring your laptop to this session and future sessions__.

# %% [markdown]
# # AstroQuery

# %% [markdown]
# [AstroQuery](https://astroquery.readthedocs.io/en/latest/) is another package that is meant to provide a lot of support for doing astonomical queries from data bases or catalogs.
#
#
#
# `AstroQuery` can be installed on your computer with Anaconda. To do so, you can enter the following command:
# ```sh
#     conda install -c conda-forge astroquery
# ```
#
# You can always update it via
# ```sh
#     conda update astroquery
# ```
# This is just a __glimpse__ of all the services and resources that `AstroQuery` has available:
#
# <img src="./images/astroquery1.png" alt="AstroQuery Features" width="600">
# <img src="./images/astroquery2.png" alt="AstroQuery Features" width="600">
# <img src="./images/astroquery3.png" alt="AstroQuery Features" width="600">
# <img src="./images/astroquery4.png" alt="AstroQuery Features" width="600">
#
#
#
#
# For purposes of today, we'll focus just on what astropy can do for units, time, coordinates, image manipulation, and more.

# %% [markdown]
# # Example: Grabbing Data from a publication from the VizieR portal with AstroQuery.
#
# ## What is VizieR?
# The VizieR Catalogue Service is an astronomical catalog service provided by Centre de données astronomiques de Strasbourg. The origin of the service dates back to 1993, when it was founded by the European Space Agency as the European Space Information System Catalogue Browser. Located at [https://vizier.cds.unistra.fr/viz-bin/VizieR](https://vizier.cds.unistra.fr/viz-bin/VizieR)
#
# ## In this example, we're grabbing a data table from [Kaltenegger et al. 2021](https://arxiv.org/pdf/2101.07898.pdf)
#
# # The data from the tables available are located on VizieR [here](https://vizier.cds.unistra.fr/viz-bin/VizieR-3?-source=J/AJ/161/233&-out.max=50&-out.form=HTML%20Table&-out.add=_r&-out.add=_RAJ,_DEJ&-sort=_r&-oc.form=sexa)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

from astroquery.vizier import Vizier
Vizier.ROW_LIMIT = -1 #without this line, Vizier won't query the entire table, just first 50 or so rows

catalog_list = Vizier.find_catalogs('Kaltenegger 2021 J/AJ/161/233')
print(catalog_list)
# Out:
# OrderedDict([('II/21A', </>), ('J/AJ/161/233', </>)])

# %%
# How many tables are there in Kaltenegger et al. 2021?
print(Vizier.get_catalogs(catalog_list))
# Out:
# TableList with 4 tables:
# 	'0:II/21A/catalog' with 12 column(s) and 629 row(s)
# 	'1:J/AJ/161/233/table3' with 24 column(s) and 4239 row(s)
# 	'2:J/AJ/161/233/table5' with 24 column(s) and 2253 row(s)
# 	'3:J/AJ/161/233/table6' with 8 column(s) and 8971 row(s)

# %%
# let's use the first table in this query (Table 3 which is index # 0)
catalog =  Vizier.get_catalogs(catalog_list)[1].to_pandas() #using to_pandas() turns this into a pandas DataFrame
catalog.head(10)
# Out:
#          TIC     RAJ2000    DEJ2000   Tmag  Teff   Mass    Rad    Lum  Dist  \
# 0    3664898  127.450266  26.773371  10.50  2814  0.124  0.099  0.001  3.58
# 1   79611981   54.003249 -44.514310   9.47  2905  0.156  0.127  0.002  3.67
# 2  274127413  298.481858  44.412973  10.35  2865  0.142  0.115  0.001  4.66
# 3  391039604  161.085375 -61.202862  10.33  2898  0.131  0.105  0.001  4.83
# 4  190138951  235.194747 -51.028056  11.10  2824  0.130  0.105  0.001  5.32
# 5  370955883  145.692189 -68.880142   9.74  3107  0.213  0.182  0.004  6.50
# 6  407688400  326.592853  38.217534   9.54  3269  0.214  0.183  0.005  7.04
# 7  219223742   62.611193 -53.612661  10.51  3087  0.164  0.135  0.002  7.11
# 8  406857100  274.743107  66.190678  10.53  3120  0.171  0.142  0.003  7.65
# 9  233068870  270.571130  64.260637  10.34  3062  0.195  0.164  0.003  7.78
#
#       ELAT     GLAT    aEA    aEM    aRV  PerEA      PerEM  PerRV       Dwell  \
# 0   7.5481  32.4155  0.024  0.075  0.029   3.91  21.280001   5.25   24.110001
# 1 -60.7761 -52.9014  0.032  0.098  0.039   5.39  28.570000   7.25   38.660000
# 2  63.1035   8.5058  0.029  0.088  0.035   4.72  25.320000   6.35   43.632999
# 3 -60.0121  -2.0131  0.027  0.082  0.033   4.49  23.850000   6.04   45.127998
# 4 -30.5227   3.3979  0.026  0.079  0.031   4.15  22.530001   5.58   21.836000
# 5 -69.4945 -11.9663  0.051  0.148  0.062   8.99  45.080002  12.14   45.127998
# 6  47.7032 -11.6124  0.056  0.160  0.069  10.48  50.509998  14.20   48.139000
# 7 -71.4636 -45.0891  0.038  0.113  0.047   6.81  34.299999   9.19   61.438999
# 8  88.0641  27.8982  0.041  0.120  0.050   7.32  36.560001   9.88  225.356003
# 9  87.6877  29.5380  0.045  0.133  0.055   7.88  39.990002  10.63  251.869003
#
#           Dur        CSD                 Gaia            _2MASS  Errors  \
# 0   27.344999   27.34502   703790044252850688  08294949+2646348  errors
# 1   50.886002   50.88554  4848140361962951552  03355969-4430453  errors
# 2   54.055000   54.05461  2079073928612821760  19535508+4424550  errors
# 3   53.014999   53.01460  5254061535097566848  10442131-6112384  errors
# 4   25.261999   25.26153  5985290231327158144  15404341-5101357  errors
# 5   53.014999   53.01460  5243594081269535872  09424635-6853060  errors
# 6   51.955002   51.95487  1952802469918554368  21462206+3813047  errors
# 7   77.632004   77.63224  4780100658292046592  04102815-5336078  errors
# 8  351.777008  105.80200  2257597439718033536  18185725+6611332  errors
# 9  325.953003  243.13900  2161121135533953536  18021660+6415445  errors
#
#    Simbad
# 0  Simbad
# 1  Simbad
# 2  Simbad
# 3  Simbad
# 4  Simbad
# 5  Simbad
# 6  Simbad
# 7  Simbad
# 8  Simbad
# 9  Simbad

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,4))
ax1=fig.add_subplot(111)

sc1=ax1.scatter(catalog['Teff'],catalog['Lum'], c=catalog['Tmag'])
ax1.set_xlabel('Effective Temperature')
ax1.set_ylabel(r'Luminosity [L$_{\odot}$]')
ax1.invert_xaxis()
cbar1=fig.colorbar(sc1)
cbar1.ax.set_ylabel('TESS mag', rotation=270,labelpad=15)
fig.suptitle('Low Mass Stars of the Revised TESS Habitable Zone Catalog',x=0.5,y=1.02,fontsize=16)
fig.tight_layout(pad=0)
plt.show()

fig = plt.figure(figsize=(8.25,4))
ax2=fig.add_subplot(111)
ax2.scatter(catalog['PerEA'],catalog['Lum'],c='green',label='Earth analog irradtion')
ax2.scatter(catalog['PerEM'],catalog['Lum'],c='Red',label='Early Mars analog irradtion')
ax2.scatter(catalog['PerRV'],catalog['Lum'],c='orange',label='Recent Venus analog irradtion')
ax2.set_xlabel('Orbital Period')
ax2.set_ylabel(r'Luminosity [L$_{\odot}$]')
ax2.legend(loc='upper right',fontsize=8,ncol=3)
ax2.set_ylim(-0.01,0.225)

fig.suptitle('Low Mass Stars of the Revised TESS Habitable Zone Catalog',x=0.5,y=1.02,fontsize=16)
fig.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Making a Hertzsprung-Russell diagram using GAIA data!
#
# To query the GAIA Data Release 3 catalog, we can do an Asynchronous queries and save our results at server side and can depend on the user files quota. These queries can be accessed at any time. For anonymous users, results are kept for three days.
#
#
# ### Quick Side note: Querying data with ADQL:
#
# ADQL is a data query language similar to SQL, built for astronomical data purposes. Its syntax is similar enough to SQL if you are familiar with it, though with some differences. In ADQL you write queries to fetch data from the database, here, from the Gaia Archive Database. If you are aware of basic level SQL, you can skip the following details:
#
# - A query has a specific structure it pertains to, just like a command. It is a compound of mainly these parts (only SELECT and FROM parts are required, others are optional) -
#
# - SELECT part- It tells the columns we want to fetch in the query. The columns can be fetched using either `column_name` directly, or in case of complex queries involving multiple tables, require table_name.column_name to avoid any column name conflicts. We can also use ADQL functions or arithmetics in the SELECT part to manipulate the data before fetching it. If we want to fetch all columns from the table, we can use `SELECT *` or `SELECT table_name.*`. We can also set the (maximum) number of rows from the top we want to query using `SELECT TOP required_number` (Similarly, for bottom rows, we can use the keyword BOTTOM).
#
# - `FROM`: tells the table we want to fetch data from. It usually consists the schema name (which is a logical sub-structure of a database) and the table name. For example, for fetching the source data from the Gaia DR3 schema, we will have to use `FROM gaiadr3.gaia_source`.
#
# - `WHERE`: tells the conditions for fetching the data. As in the above example, we used two conditions other than the globular cluster name. These can be written as `WHERE gaia_source.parallax>=5` AND `gaia_source.parallax_over_error>=20`, where `AND` is a restricted keyword in ADQL used to signify that both these conditions must be met for the queried rows
#
# - `ORDER BY`: tells how the data should be Ordered before fetching the data. We can use one or more colums to order the data on and DESC or ASC are used to specify the ordering to be Descending or Ascending respectively. The data is only ordered for the query and no changes are made in the actual data table. If we need the data to be ordered randomly, we need to use `ORDER BY` random_item, where random_item is a restricted keyword in ADQL.
#
# - So, a simple query structure is `SELECT <columns> FROM <tables> WHERE <conditions> ORDER BY <columns>`
#
# There are more such parts we can add like `GROUP BY` (to create factor sets/subsets that have identical values for one or more columns, used to compute aggregates), `INNER JOIN` (to make computations on one or more referenced columns within a table), `OUTER JOIN` (to make computation based on multiple tables lined by one or more referenced columns), etc. The main distiction between SQL and ADQL is the addition of Geometric extension functions to SQL.
#
#
# #### Writing a simple query:
# We're going to now look at a very simple ADQL query - Let's select the 100 stars closest to Earth (so, with the largest parallaxes) using ADQL. The syntax for this query goes as follows:
#
# We select the top 100 results:
#
# `SELECT TOP 100`
#
# ...and the following columns:
#
# `gaia_source.source_id, gaia_source.ra, gaia_source.ra_error, gaia_source.dec, gaia_source.dec_error, gaia_source.parallax, gaia_source.parallax_error`
#
# ...from the DR3 Source catalog:
#
# `FROM gaiadr3.gaia_source`
#
# ...where the parallax is greater than 0 (to avoid issues with improperly catalogued parallaxes):
#
# `WHERE gaia_source.parallax >= 0`
#
# ...and the results are in descending order by parallax to get the top 100 entries with maximum parallax:
#
# `ORDER BY gaia_source.parallax DESC`
#
# Putting the whole query together:
#
# `SELECT TOP 100 gaia_source.source_id, gaia_source.ra, gaia_source.ra_error, gaia_source.dec, gaia_source.dec_error, gaia_source.parallax, gaia_source.parallax_error FROM gaiadr3.gaia_source WHERE gaia_source.parallax >= 0 ORDER BY gaia_source.parallax DESC`
#
# ### Back to our cross-matching example
#
#
# Queries retrieved results can be stored locally in memory (by default) or in a file.

# %%
def send_radial_gaia_query(query_size=1000000, distance=200, **kwargs):
    """
    Sends an archive query for d < 200 pc, with additional filters taken from
    Gaia Data Release 3: Observational Hertzsprung-Russell diagrams (Sect. 2.1)
    Gaia Collaboration, Babusiaux et al. 2018
    (https://doi.org/10.1051/0004-6361/201832843)

    NOTE: 10000000 is a maximum query size (~76 MB / column)

    Additional keyword arguments are passed to TapPlus.launch_job_async method.
    """    
    from astroquery.gaia import Gaia
    # This query uses ADQL syntax to submit a query
    # We are using a set of criteria outlined by Babusiaux et al. 2018
    job = Gaia.launch_job_async("select top {}".format(query_size)+
                #" lum_val, teff_val,"
                #" ra, dec, parallax,"
                " bp_rp, phot_g_mean_mag+5*log10(parallax)-10 as mg"
         " from gaiadr3.gaia_source"
         " where parallax_over_error > 10"
         " and visibility_periods_used > 8"
         " and phot_g_mean_flux_over_error > 50"
         " and phot_bp_mean_flux_over_error > 20"
         " and phot_rp_mean_flux_over_error > 20"
         " and phot_bp_rp_excess_factor <"
            " 1.3+0.06*power(phot_bp_mean_mag-phot_rp_mean_mag,2)"
         " and phot_bp_rp_excess_factor >"
            " 1.0+0.015*power(phot_bp_mean_mag-phot_rp_mean_mag,2)"
         " and astrometric_chi2_al/(astrometric_n_good_obs_al-5)<"
            "1.44*greatest(1,exp(-0.4*(phot_g_mean_mag-19.5)))"
         +" and 1000/parallax <= {}".format(distance), **kwargs)

    return job

# %%
# run job, this may take a while (~30min)
import numpy as np
import pandas as pd
try:
    gaiarec = pd.read_csv("gaia-hrd-dr3-200pc.csv")
    bp_rp, mg = gaiarec.bp_rp, gaiarec.mg
except (FileNotFoundError,OSError) as e:
    print(e)
    job = send_radial_gaia_query(dump_to_file=True, output_format="csv",
                                 output_file="gaia-hrd-dr3-200pc.csv",
                                 query_size=10000000)
    gaiarec = job.get_results()
    bp_rp = gaiarec['bp_rp'].data
    mg = gaiarec['mg'].data

# %%
gaiarec.head(10)
# Out:
#       bp_rp         mg
# 0  0.795505   4.572111
# 1  2.165551   9.105893
# 2  1.269135   6.458955
# 3  2.588948  11.339489
# 4  2.755577  11.013251
# 5  0.010123   1.487231
# 6  2.691968  10.502093
# 7  2.538270  10.136544
# 8  0.440062   2.684663
# 9  1.204395   6.171388

# %%
# plot the H-R diagram for 1 M stars within 200 pc from the Sun
import matplotlib.pyplot as plt
from matplotlib import colors
# plt.rc('text', usetex=True)

fig, ax = plt.subplots(figsize=(12, 6))
# only show 2D-histogram for bins with more than 10 stars in them
h = ax.hist2d(bp_rp, mg, bins=300, cmin=10, norm=colors.PowerNorm(0.5), zorder=0.5)
# fill the rest with scatter (set rasterized=True if saving as vector graphics)
ax.scatter(bp_rp, mg, alpha=0.05, s=1, color='k', zorder=0)
ax.set_xlim(-1,6)
ax.set_ylim(-3,18)
ax.invert_yaxis()
cb = fig.colorbar(h[3], ax=ax, pad=0.02)
ax.set_xlabel(r'$G_{BP} - G_{RP}$')
ax.set_ylabel(r'$M_{G}$')
cb.set_label("Stellar Density",rotation=270,labelpad=15)
plt.show()

# %% [markdown]
# # Finding individual stars

# %%
from astroquery.vizier import Vizier
result = Vizier.query_object("Proxima Centauri")
print(result)
# Out:
# WARNING: UnitsWarning: The unit 'a' has been deprecated in the VOUnit standard. Suggested: 365.25d. [astropy.units.format.utils]
# WARNING: UnitsWarning: The unit 'pix' has been deprecated in the VOUnit standard. [astropy.units.format.utils]
# WARNING: UnitsWarning: The unit 'ct' has been deprecated in the VOUnit standard. [astropy.units.format.utils]
# WARNING: UnitsWarning: Unit 'Sun' not supported by the VOUnit standard. Did you mean uN? [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'pct' not supported by the VOUnit standard. Did you mean 1e+15count, PC, PT, Pct (deprecated), pC, pT or pc? [astropy.units.format.vounit]
# WARNING: UnitsWarning: The unit 'ph' has been deprecated in the VOUnit standard. [astropy.units.format.utils]
# WARNING: UnitsWarning: Unit 'x' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: The unit 'au' has been deprecated in the VOUnit standard. Suggested: 1.4959787e+11m. [astropy.units.format.utils]
# WARNING: UnitsWarning: Unit 'Earth' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'bar' not supported by the VOUnit standard. Did you mean 1e-28m**2, Ba (deprecated), aR, barn (deprecated) or cm**-1.g.s**-2? [astropy.units.format.vounit]
# TableList with 371 tables:
# 	'0:METAobj' with 5 column(s) and 11 row(s)
# 	'1:ReadMeObj' with 5 column(s) and 11 row(s)
# 	'2:I/87B/catalog' with 13 column(s) and 1 row(s)
# 	'3:I/196/main' with 14 column(s) and 1 row(s)
# 	'4:I/196/annex1' with 10 column(s) and 1 row(s)
# 	'5:I/197A/tic' with 10 column(s) and 3 row(s)
# 	'6:I/230/shb' with 15 column(s) and 1 row(s)
# 	'7:I/239/hip_main' with 14 column(s) and 1 row(s)
# 	'8:I/239/tyc_main' with 11 column(s) and 1 row(s)
# 	'9:I/252/out' with 8 column(s) and 152 row(s)
# 	'10:I/255/out' with 9 column(s) and 10 row(s)
# 	'11:I/259/tyc2' with 10 column(s) and 1 row(s)
# 	'12:I/271/out' with 11 column(s) and 219 row(s)
# 	'13:I/279/catalog' with 11 column(s) and 1 row(s)
# 	'14:I/280B/ascc' with 12 column(s) and 1 row(s)
# 	'15:I/284/out' with 14 column(s) and 600 row(s)
# 	'16:I/289/out' with 13 column(s) and 29 row(s)
# 	'17:I/294A/ucac2bss' with 12 column(s) and 1 row(s)
# 	'18:I/297/out' with 19 column(s) and 650 row(s)
# 	'19:I/305/out' with 11 column(s) and 297 row(s)
# 	'20:I/311/hip2' with 13 column(s) and 1 row(s)
# 	'21:I/312/sample' with 13 column(s) and 4 row(s)
# 	'22:I/317/sample' with 13 column(s) and 528 row(s)
# 	'23:I/319/xpm' with 25 column(s) and 130 row(s)
# 	'24:I/320/spm4' with 21 column(s) and 108 row(s)
# 	'25:I/322A/out' with 24 column(s) and 57 row(s)
# 	'26:I/324/igsl3' with 18 column(s) and 427 row(s)
# 	'27:I/337/gaia' with 14 column(s) and 865 row(s)
# 	'28:I/339/hsoy' with 18 column(s) and 280 row(s)
# 	'29:I/340/ucac5' with 20 column(s) and 54 row(s)
# 	'30:I/345/gaia2' with 32 column(s) and 1375 row(s)
# 	'31:I/347/gaia2dis' with 9 column(s) and 1113 row(s)
# 	'32:I/348/catalog' with 35 column(s) and 1 row(s)
# 	'33:I/349/starhorse' with 19 column(s) and 157 row(s)
# 	'34:I/350/gaiaedr3' with 39 column(s) and 1417 row(s)
# 	'35:I/350/tyc2tdsc' with 16 column(s) and 1 row(s)
# 	'36:I/350/comscanl' with 13 column(s) and 2 row(s)
# 	'37:I/352/gedr3dis' with 10 column(s) and 1139 row(s)
# 	'38:I/353/gsc242' with 35 column(s) and 902 row(s)
# 	'39:I/354/starhorse2021' with 20 column(s) and 205 row(s)
# 	'40:I/355/gaiadr3' with 57 column(s) and 1417 row(s)
# 	'41:I/355/paramp' with 24 column(s) and 1227 row(s)
# 	'42:I/355/paramsup' with 24 column(s) and 267 row(s)
# 	'43:I/355/epphot' with 48 column(s) and 993 row(s)
# 	'44:I/355/rvsmean' with 9 column(s) and 2401 row(s)
# 	'45:I/355/xpsummary' with 22 column(s) and 132 row(s)
# 	'46:I/355/xpsample' with 6 column(s) and 5488 row(s)
# 	'47:I/355/xpcont' with 26 column(s) and 132 row(s)
# 	'48:I/355/spectra' with 5 column(s) and 16 row(s)
# 	'49:I/356/galcand' with 10 column(s) and 1 row(s)
# 	'50:I/358/varisum' with 24 column(s) and 10 row(s)
# 	'51:I/358/vclassre' with 6 column(s) and 10 row(s)
# 	'52:I/358/vlpv' with 9 column(s) and 4 row(s)
# 	'53:I/360/goldf' with 23 column(s) and 1 row(s)
# 	'54:I/360/goldoba' with 4 column(s) and 3 row(s)
# 	'55:I/360/syntphot' with 5 column(s) and 132 row(s)
# 	'56:I/361/lenscand' with 18 column(s) and 5 row(s)
# 	'57:I/361/lenscatn' with 5 column(s) and 1 row(s)
# 	'58:I/361/lensobs' with 10 column(s) and 422 row(s)
# 	'59:I/361/lensout' with 11 column(s) and 59 row(s)
# 	'60:II/7A/catalog' with 17 column(s) and 3 row(s)
# 	'61:II/55/catalog' with 11 column(s) and 1 row(s)
# 	'62:II/122B/merged' with 12 column(s) and 3 row(s)
# 	'63:II/125/main' with 13 column(s) and 1 row(s)
# 	'64:II/168/ubvmeans' with 15 column(s) and 1 row(s)
# 	'65:II/224/cadars' with 12 column(s) and 4 row(s)
# 	'66:II/246/out' with 15 column(s) and 279 row(s)
# 	'67:II/275/fsr' with 15 column(s) and 1 row(s)
# 	'68:II/275/assoc' with 14 column(s) and 2 row(s)
# 	'69:II/297/irc' with 13 column(s) and 1 row(s)
# 	'70:II/298/fis' with 15 column(s) and 1 row(s)
# 	'71:II/311/wise' with 22 column(s) and 35 row(s)
# 	'72:II/328/allwise' with 28 column(s) and 71 row(s)
# 	'73:II/336/apass9' with 20 column(s) and 20 row(s)
# 	'74:II/337/vvv1' with 19 column(s) and 2134 row(s)
# 	'75:II/338/catalog' with 23 column(s) and 1 row(s)
# 	'76:II/339/uvotssc1' with 24 column(s) and 998 row(s)
# 	'77:II/339/summary' with 5 column(s) and 13 row(s)
# 	'78:II/340/xmmom2_1' with 46 column(s) and 718 row(s)
# 	'79:II/340/summary' with 19 column(s) and 4 row(s)
# 	'80:II/345/jmdc' with 16 column(s) and 2 row(s)
# 	'81:II/348/vvv2' with 19 column(s) and 2511 row(s)
# 	'82:II/354/hipext' with 12 column(s) and 1 row(s)
# 	'83:II/356/xmmom41s' with 44 column(s) and 729 row(s)
# 	'84:II/358/smss' with 30 column(s) and 184 row(s)
# 	'85:II/360/catalog' with 21 column(s) and 24 row(s)
# 	'86:II/361/mdfc-v10' with 22 column(s) and 1 row(s)
# 	'87:II/363/unwise' with 11 column(s) and 350 row(s)
# 	'88:II/364/virac' with 25 column(s) and 1313 row(s)
# 	'89:II/365/catwise' with 38 column(s) and 158 row(s)
# 	'90:II/366/catalog' with 23 column(s) and 1 row(s)
# 	'91:II/368/sstsl2' with 37 column(s) and 173 row(s)
# 	'92:II/370/xmmom5s' with 44 column(s) and 1382 row(s)
# 	'93:II/374/table2' with 11 column(s) and 125 row(s)
# 	'94:II/376/vvv4' with 76 column(s) and 3286 row(s)
# 	'95:II/378/xmmom6s' with 44 column(s) and 1297 row(s)
# 	'96:II/379/smssdr4' with 22 column(s) and 588 row(s)
# 	'97:III/198/main' with 24 column(s) and 1 row(s)
# 	'98:III/223/mk12' with 9 column(s) and 1 row(s)
# 	'99:III/249/catalog' with 14 column(s) and 6 row(s)
# 	'100:III/284/allstars' with 99 column(s) and 2 row(s)
# 	'101:III/284/allvis' with 10 column(s) and 4 row(s)
# 	'102:III/286/catalog' with 92 column(s) and 2 row(s)
# 	'103:III/286/allvis' with 22 column(s) and 4 row(s)
# 	'104:IV/35/wn18_b10' with 18 column(s) and 40 row(s)
# 	'105:IV/38/tic' with 48 column(s) and 1395 row(s)
# 	'106:IV/39/tic82' with 48 column(s) and 1396 row(s)
# 	'107:V/51/disco' with 10 column(s) and 3 row(s)
# 	'108:V/68A/table1' with 10 column(s) and 1 row(s)
# 	'109:V/114/msx6_gp' with 16 column(s) and 1 row(s)
# 	'110:V/137D/XHIP' with 15 column(s) and 1 row(s)
# 	'111:V/155/gdr2ap' with 22 column(s) and 17 row(s)
# 	'112:V/158/morxv2' with 30 column(s) and 6 row(s)
# 	'113:VI/42/out' with 3 column(s) and 1 row(s)
# 	'114:VI/110/inescat' with 7 column(s) and 79 row(s)
# 	'115:VI/117/asca' with 9 column(s) and 2 row(s)
# 	'116:VI/129/fuse' with 10 column(s) and 2 row(s)
# 	'117:IX/6/data' with 15 column(s) and 1 row(s)
# 	'118:IX/8/catalog' with 10 column(s) and 1 row(s)
# 	'119:IX/13/2e' with 10 column(s) and 2 row(s)
# 	'120:IX/25/ipcfield' with 8 column(s) and 1 row(s)
# 	'121:IX/25/ipcihut' with 9 column(s) and 4 row(s)
# 	'122:IX/30/2rxp' with 9 column(s) and 11 row(s)
# 	'123:IX/30/seqp' with 8 column(s) and 4 row(s)
# 	'124:IX/31/wgacat' with 12 column(s) and 6 row(s)
# 	'125:IX/35/survey' with 10 column(s) and 1 row(s)
# 	'126:IX/35/faint' with 9 column(s) and 1 row(s)
# 	'127:IX/43/sources' with 16 column(s) and 2 row(s)
# 	'128:IX/43/xcor' with 7 column(s) and 32 row(s)
# 	'129:IX/45/csc11' with 18 column(s) and 2 row(s)
# 	'130:IX/47/3xmmeu' with 23 column(s) and 10 row(s)
# 	'131:IX/48/xgustwra' with 46 column(s) and 6 row(s)
# 	'132:IX/50/xmm3r6s' with 17 column(s) and 11 row(s)
# 	'133:IX/50/summary' with 6 column(s) and 4 row(s)
# 	'134:IX/54/xmm3r7s' with 17 column(s) and 11 row(s)
# 	'135:IX/54/summary' with 7 column(s) and 4 row(s)
# 	'136:IX/55/xmm3r8s' with 17 column(s) and 11 row(s)
# 	'137:IX/55/summary' with 7 column(s) and 4 row(s)
# 	'138:IX/57/csc2master' with 79 column(s) and 20 row(s)
# 	'139:IX/58/2sxps' with 12 column(s) and 5 row(s)
# 	'140:IX/58/2sxpscle' with 12 column(s) and 4 row(s)
# 	'141:IX/59/xmm4dr9s' with 17 column(s) and 11 row(s)
# 	'142:IX/59/summary' with 7 column(s) and 4 row(s)
# 	'143:IX/61/xmm4r9st' with 23 column(s) and 24 row(s)
# 	'144:IX/63/xmm4d10s' with 16 column(s) and 21 row(s)
# 	'145:IX/63/summary' with 7 column(s) and 7 row(s)
# 	'146:IX/64/xmm410st' with 23 column(s) and 104 row(s)
# 	'147:IX/65/xmm4d11s' with 16 column(s) and 21 row(s)
# 	'148:IX/65/summary' with 7 column(s) and 7 row(s)
# 	'149:IX/66/xmm411st' with 23 column(s) and 112 row(s)
# 	'150:IX/68/xmm4d12s' with 16 column(s) and 21 row(s)
# 	'151:IX/68/summary' with 7 column(s) and 7 row(s)
# 	'152:IX/69/xmm4d13s' with 16 column(s) and 21 row(s)
# 	'153:IX/69/summary' with 7 column(s) and 7 row(s)
# 	'154:B/denis/denis' with 15 column(s) and 348 row(s)
# 	'155:B/hst/obscore' with 12 column(s) and 9228 row(s)
# 	'156:B/hst/hstlog' with 9 column(s) and 1011 row(s)
# 	'157:B/chandra/chandra' with 11 column(s) and 16 row(s)
# 	'158:B/xmm/xmmlog' with 11 column(s) and 9 row(s)
# 	'159:B/mk/mktypes' with 11 column(s) and 9 row(s)
# 	'160:B/gcvs/gcvs_cat' with 11 column(s) and 1 row(s)
# 	'161:B/wds/wds' with 18 column(s) and 1 row(s)
# 	'162:B/vsx/vsx' with 20 column(s) and 2 row(s)
# 	'163:B/pastel/pastel' with 16 column(s) and 2 row(s)
# 	'164:B/assocdata/obscore' with 13 column(s) and 2 row(s)
# 	'165:B/gemini/obscore' with 11 column(s) and 160 row(s)
# 	'166:B/swift/swiftlog' with 10 column(s) and 54 row(s)
# 	'167:J/ApJ/582/1011/table2' with 12 column(s) and 1 row(s)
# 	'168:J/ApJ/743/48/catalog' with 16 column(s) and 1 row(s)
# 	'169:J/ApJ/743/141/table1' with 16 column(s) and 1 row(s)
# 	'170:J/ApJ/753/156/table4' with 16 column(s) and 1 row(s)
# 	'171:J/ApJ/786/20/table7' with 16 column(s) and 1 row(s)
# 	'172:J/ApJ/808/194/table8' with 15 column(s) and 1 row(s)
# 	'173:J/ApJ/813/28/table4' with 14 column(s) and 2 row(s)
# 	'174:J/ApJ/817/1/table3' with 27 column(s) and 1 row(s)
# 	'175:J/ApJ/817/112/highpm' with 23 column(s) and 1 row(s)
# 	'176:J/ApJ/834/17/table1' with 11 column(s) and 1 row(s)
# 	'177:J/ApJ/834/85/table1' with 15 column(s) and 1 row(s)
# 	'178:J/ApJ/843/31/mdwarfs' with 22 column(s) and 1 row(s)
# 	'179:J/ApJ/867/105/refcat2' with 23 column(s) and 823 row(s)
# 	'180:J/ApJ/878/134/table2' with 17 column(s) and 1 row(s)
# 	'181:J/ApJ/878/134/table3' with 27 column(s) and 1 row(s)
# 	'182:J/ApJ/880/L1/table1' with 17 column(s) and 1 row(s)
# 	'183:J/ApJ/887/261/table5' with 15 column(s) and 1 row(s)
# 	'184:J/ApJ/887/261/table6' with 15 column(s) and 1 row(s)
# 	'185:J/ApJ/890/23/table1' with 32 column(s) and 1 row(s)
# 	'186:J/ApJ/891/58/table6' with 18 column(s) and 1 row(s)
# 	'187:J/ApJ/902/115/table1' with 22 column(s) and 1 row(s)
# 	'188:J/ApJ/905/107/table1' with 17 column(s) and 1 row(s)
# 	'189:J/ApJ/926/204/stars' with 6 column(s) and 1 row(s)
# 	'190:J/ApJ/935/104/table1' with 26 column(s) and 1 row(s)
# 	'191:J/ApJ/935/L9/table12' with 18 column(s) and 1 row(s)
# 	'192:J/ApJ/941/104/table8' with 35 column(s) and 5 row(s)
# 	'193:J/ApJS/184/138/table3' with 12 column(s) and 1 row(s)
# 	'194:J/ApJS/187/149/starcat' with 11 column(s) and 1 row(s)
# 	'195:J/ApJS/200/15/stars' with 10 column(s) and 1 row(s)
# 	'196:J/ApJS/201/19/plx-phot' with 15 column(s) and 1 row(s)
# 	'197:J/ApJS/202/14/table1' with 18 column(s) and 1 row(s)
# 	'198:J/ApJS/202/14/table2' with 19 column(s) and 1 row(s)
# 	'199:J/ApJS/211/9/table1' with 23 column(s) and 1 row(s)
# 	'200:J/ApJS/224/36/motionobj' with 17 column(s) and 1 row(s)
# 	'201:J/ApJS/224/40/table5' with 15 column(s) and 9 row(s)
# 	'202:J/ApJS/224/40/counts' with 34 column(s) and 13 row(s)
# 	'203:J/ApJS/235/6/catalog' with 18 column(s) and 1 row(s)
# 	'204:J/ApJS/247/11/table5' with 21 column(s) and 1 row(s)
# 	'205:J/ApJS/249/16/tablec1' with 9 column(s) and 1 row(s)
# 	'206:J/ApJS/254/42/catalog' with 29 column(s) and 1 row(s)
# 	'207:J/ApJS/261/26/table4' with 12 column(s) and 75 row(s)
# 	'208:J/ApJS/264/41/catalog' with 30 column(s) and 1 row(s)
# 	'209:J/ApJS/266/6/tablea1' with 21 column(s) and 1 row(s)
# 	'210:J/ApJS/266/6/table3' with 21 column(s) and 1 row(s)
# 	'211:J/ApJS/266/6/table4' with 22 column(s) and 1 row(s)
# 	'212:J/ApJS/266/6/tableb1' with 20 column(s) and 1 row(s)
# 	'213:J/A+A/325/159/table1' with 9 column(s) and 1 row(s)
# 	'214:J/A+A/397/147/stars' with 5 column(s) and 1 row(s)
# 	'215:J/A+A/397/997/table7' with 11 column(s) and 1 row(s)
# 	'216:J/A+A/403/247/table7' with 12 column(s) and 1 row(s)
# 	'217:J/A+A/414/699/table2' with 11 column(s) and 1 row(s)
# 	'218:J/A+A/417/651/table1' with 14 column(s) and 3 row(s)
# 	'219:J/A+A/431/773/charm2' with 13 column(s) and 2 row(s)
# 	'220:J/A+A/439/1137/stars' with 5 column(s) and 1 row(s)
# 	'221:J/A+A/460/695/stars' with 15 column(s) and 1 row(s)
# 	'222:J/A+A/469/309/table2' with 14 column(s) and 1 row(s)
# 	'223:J/A+A/478/507/stars' with 14 column(s) and 1 row(s)
# 	'224:J/A+A/493/339/obs' with 8 column(s) and 1 row(s)
# 	'225:J/A+A/493/339/target' with 10 column(s) and 1 row(s)
# 	'226:J/A+A/505/859/targets' with 16 column(s) and 1 row(s)
# 	'227:J/A+A/541/A9/stars' with 7 column(s) and 1 row(s)
# 	'228:J/A+A/542/A48/ambredr1' with 21 column(s) and 3 row(s)
# 	'229:J/A+A/546/A61/tablea1' with 18 column(s) and 1 row(s)
# 	'230:J/A+A/548/A79/omc-var' with 17 column(s) and 1 row(s)
# 	'231:J/A+A/549/A109/table3' with 19 column(s) and 1 row(s)
# 	'232:J/A+A/551/A36/table2' with 15 column(s) and 1 row(s)
# 	'233:J/A+A/551/A142/1swxrt' with 14 column(s) and 22 row(s)
# 	'234:J/A+A/551/L8/sindices' with 9 column(s) and 1 row(s)
# 	'235:J/A+A/556/A15/stars' with 16 column(s) and 1 row(s)
# 	'236:J/A+A/575/A35/table3' with 21 column(s) and 1 row(s)
# 	'237:J/A+A/588/A103/cat2rxs' with 35 column(s) and 1 row(s)
# 	'238:J/A+A/594/A116/nhi_hpx' with 6 column(s) and 1 row(s)
# 	'239:J/A+A/596/A49/maincat' with 12 column(s) and 1 row(s)
# 	'240:J/A+A/600/A13/tablea3' with 19 column(s) and 1 row(s)
# 	'241:J/A+A/606/A39/ocsvm_an' with 12 column(s) and 1 row(s)
# 	'242:J/A+A/616/A108/catalog' with 12 column(s) and 1 row(s)
# 	'243:J/A+A/623/A72/hipgpma' with 42 column(s) and 1 row(s)
# 	'244:J/A+A/624/A49/stars' with 8 column(s) and 1 row(s)
# 	'245:J/A+A/624/A94/tablea1' with 14 column(s) and 1 row(s)
# 	'246:J/A+A/625/A122/cielorgs' with 18 column(s) and 62 row(s)
# 	'247:J/A+A/629/A139/table3' with 16 column(s) and 1 row(s)
# 	'248:J/A+A/636/A74/list' with 12 column(s) and 1 row(s)
# 	'249:J/A+A/638/A20/tableb1' with 26 column(s) and 1 row(s)
# 	'250:J/A+A/638/A76/apogee' with 14 column(s) and 1 row(s)
# 	'251:J/A+A/638/A120/list' with 7 column(s) and 13 row(s)
# 	'252:J/A+A/640/A2/m_dwarfs' with 17 column(s) and 2 row(s)
# 	'253:J/A+A/640/A83/table' with 12 column(s) and 5 row(s)
# 	'254:J/A+A/642/A115/tablea3' with 39 column(s) and 1 row(s)
# 	'255:J/A+A/644/A67/table2' with 18 column(s) and 1 row(s)
# 	'256:J/A+A/644/A68/tablea1' with 20 column(s) and 1 row(s)
# 	'257:J/A+A/645/A100/targets' with 28 column(s) and 1 row(s)
# 	'258:J/A+A/645/A100/40pclist' with 18 column(s) and 1 row(s)
# 	'259:J/A+A/648/A44/tabled1' with 41 column(s) and 16 row(s)
# 	'260:J/A+A/649/A6/table1c' with 31 column(s) and 1 row(s)
# 	'261:J/A+A/649/A6/table1r' with 31 column(s) and 2 row(s)
# 	'262:J/A+A/650/A201/tablea1' with 28 column(s) and 2 row(s)
# 	'263:J/A+A/654/A20/table1' with 20 column(s) and 1 row(s)
# 	'264:J/A+A/654/A168/tablee2' with 17 column(s) and 1 row(s)
# 	'265:J/A+A/657/A7/tablea1' with 52 column(s) and 1 row(s)
# 	'266:J/A+A/657/A7/tablea2' with 43 column(s) and 1 row(s)
# 	'267:J/A+A/657/A7/tablea3' with 43 column(s) and 4 row(s)
# 	'268:J/A+A/657/A138/table6' with 13 column(s) and 4 row(s)
# 	'269:J/A+A/657/A138/table7' with 13 column(s) and 4 row(s)
# 	'270:J/A+A/659/A3/table2' with 20 column(s) and 1 row(s)
# 	'271:J/A+A/659/A95/sos' with 12 column(s) and 2 row(s)
# 	'272:J/A+A/659/A95/apogee' with 18 column(s) and 2 row(s)
# 	'273:J/A+A/660/A34/table' with 10 column(s) and 1 row(s)
# 	'274:J/A+A/661/A23/tableb1' with 20 column(s) and 1 row(s)
# 	'275:J/A+A/661/A89/table1' with 36 column(s) and 1 row(s)
# 	'276:J/A+A/662/A15/table1' with 20 column(s) and 1 row(s)
# 	'277:J/A+A/664/A105/main' with 14 column(s) and 2 row(s)
# 	'278:J/A+A/665/A78/agnev' with 3 column(s) and 6 row(s)
# 	'279:J/A+A/665/A78/bkgev' with 3 column(s) and 45 row(s)
# 	'280:J/A+A/665/A78/agnin' with 15 column(s) and 2 row(s)
# 	'281:J/A+A/669/A104/catalog' with 37 column(s) and 19 row(s)
# 	'282:J/A+A/670/A19/cns5' with 31 column(s) and 1 row(s)
# 	'283:J/A+A/670/A102/tableb2' with 16 column(s) and 1 row(s)
# 	'284:J/A+A/672/A37/table1' with 22 column(s) and 1 row(s)
# 	'285:J/A+A/673/A155/apogee17' with 10 column(s) and 2 row(s)
# 	'286:J/A+A/673/A155/gaiarvs' with 9 column(s) and 2 row(s)
# 	'287:J/A+A/674/A25/vspursig' with 40 column(s) and 10 row(s)
# 	'288:J/A+A/675/A68/members' with 11 column(s) and 1 row(s)
# 	'289:J/A+A/675/A168/tableb1' with 13 column(s) and 1 row(s)
# 	'290:J/A+A/676/A129/catalog' with 16 column(s) and 1 row(s)
# 	'291:J/A+A/677/A137/catalog' with 30 column(s) and 79 row(s)
# 	'292:J/A+A/678/A96/tableg1' with 17 column(s) and 1 row(s)
# 	'293:J/A+A/682/A34/erass1-m' with 24 column(s) and 2 row(s)
# 	'294:J/A+A/683/A125/table4' with 18 column(s) and 414 row(s)
# 	'295:J/A+A/684/A106/tablea1' with 18 column(s) and 1 row(s)
# 	'296:J/A+A/684/A121/pos_ctp' with 21 column(s) and 1 row(s)
# 	'297:J/A+A/685/A59/catalog' with 18 column(s) and 1 row(s)
# 	'298:J/A+A/685/A130/table2' with 13 column(s) and 26 row(s)
# 	'299:J/A+A/686/A239/stars' with 33 column(s) and 1 row(s)
# 	'300:J/A+A/687/A250/catalog' with 26 column(s) and 23 row(s)
# 	'301:J/A+AS/114/465/table2' with 9 column(s) and 8 row(s)
# 	'302:J/A+AS/114/465/table4' with 8 column(s) and 2 row(s)
# 	'303:J/A+AS/124/437/catalog' with 9 column(s) and 1 row(s)
# 	'304:J/AJ/141/129/table6' with 14 column(s) and 1 row(s)
# 	'305:J/AJ/144/64/table2' with 18 column(s) and 1 row(s)
# 	'306:J/AJ/150/6/table1' with 18 column(s) and 1 row(s)
# 	'307:J/AJ/153/95/table3' with 17 column(s) and 1 row(s)
# 	'308:J/AJ/155/39/table5' with 10 column(s) and 2 row(s)
# 	'309:J/AJ/155/122/table5' with 19 column(s) and 1 row(s)
# 	'310:J/AJ/155/180/table1' with 18 column(s) and 1 row(s)
# 	'311:J/AJ/155/265/results' with 19 column(s) and 1 row(s)
# 	'312:J/AJ/156/102/table9' with 10 column(s) and 1 row(s)
# 	'313:J/AJ/156/217/table1' with 18 column(s) and 1 row(s)
# 	'314:J/AJ/157/52/table1' with 21 column(s) and 1 row(s)
# 	'315:J/AJ/158/56/table2' with 22 column(s) and 1 row(s)
# 	'316:J/AJ/158/56/table1' with 10 column(s) and 1 row(s)
# 	'317:J/AJ/158/93/table2' with 5 column(s) and 66 row(s)
# 	'318:J/AJ/158/122/table1' with 4 column(s) and 1 row(s)
# 	'319:J/AJ/158/251/table1' with 14 column(s) and 1 row(s)
# 	'320:J/AJ/159/18/table2' with 14 column(s) and 1 row(s)
# 	'321:J/AJ/159/84/table2' with 5 column(s) and 66 row(s)
# 	'322:J/AJ/160/84/tablea1' with 16 column(s) and 1 row(s)
# 	'323:J/AJ/160/215/table2' with 7 column(s) and 1 row(s)
# 	'324:J/AJ/160/279/table1' with 4 column(s) and 2 row(s)
# 	'325:J/AJ/161/63/table3' with 34 column(s) and 1 row(s)
# 	'326:J/AJ/161/234/table2' with 62 column(s) and 2 row(s)
# 	'327:J/AJ/161/234/table3' with 17 column(s) and 10 row(s)
# 	'328:J/AJ/161/234/table4' with 19 column(s) and 3 row(s)
# 	'329:J/AJ/163/152/table1' with 12 column(s) and 2 row(s)
# 	'330:J/AJ/163/178/table1' with 17 column(s) and 1 row(s)
# 	'331:J/AJ/164/58/table3' with 11 column(s) and 4 row(s)
# 	'332:J/AJ/165/34/table1' with 29 column(s) and 1 row(s)
# 	'333:J/AJ/165/168/table2' with 19 column(s) and 1 row(s)
# 	'334:J/AJ/165/265/table1' with 14 column(s) and 1 row(s)
# 	'335:J/AJ/165/267/table1' with 27 column(s) and 1 row(s)
# 	'336:J/AJ/166/16/table1' with 20 column(s) and 1 row(s)
# 	'337:J/AJ/166/236/table4' with 8 column(s) and 1 row(s)
# 	'338:J/AJ/166/236/table6' with 11 column(s) and 1 row(s)
# 	'339:J/AJ/167/159/table3' with 12 column(s) and 1 row(s)
# 	'340:J/PASP/122/885/table1' with 15 column(s) and 1 row(s)
# 	'341:J/PASP/129/E4501/table1' with 10 column(s) and 1 row(s)
# 	'342:J/PASP/131/C4401/table1' with 15 column(s) and 1 row(s)
# 	'343:J/MNRAS/260/77/table1' with 8 column(s) and 1 row(s)
# 	'344:J/MNRAS/274/1165/catalog' with 11 column(s) and 1 row(s)
# 	'345:J/MNRAS/372/163/table2' with 12 column(s) and 1 row(s)
# 	'346:J/MNRAS/403/1089/table4' with 10 column(s) and 1 row(s)
# 	'347:J/MNRAS/427/2917/table2' with 17 column(s) and 1 row(s)
# 	'348:J/MNRAS/443/2561/stars' with 24 column(s) and 1 row(s)
# 	'349:J/MNRAS/449/2618/table1' with 21 column(s) and 1 row(s)
# 	'350:J/MNRAS/454/3267/table1' with 16 column(s) and 1 row(s)
# 	'351:J/MNRAS/458/3479/clasiii' with 19 column(s) and 2 row(s)
# 	'352:J/MNRAS/463/4210/ucac4rpm' with 12 column(s) and 4 row(s)
# 	'353:J/MNRAS/471/770/table2' with 52 column(s) and 1 row(s)
# 	'354:J/MNRAS/476/1224/table3' with 10 column(s) and 1 row(s)
# 	'355:J/MNRAS/485/3999/tablea1' with 14 column(s) and 1 row(s)
# 	'356:J/MNRAS/486/251/tablea1' with 20 column(s) and 1 row(s)
# 	'357:J/MNRAS/495/1943/table3' with 18 column(s) and 1 row(s)
# 	'358:J/MNRAS/498/5720/catalog' with 19 column(s) and 905 row(s)
# 	'359:J/MNRAS/503/3660/table7' with 13 column(s) and 1 row(s)
# 	'360:J/MNRAS/503/3975/catalog' with 17 column(s) and 1 row(s)
# 	'361:J/MNRAS/503/5263/table10' with 11 column(s) and 11 row(s)
# 	'362:J/MNRAS/519/6210/table1' with 21 column(s) and 1 row(s)
# 	'363:J/MNRAS/522/29/table2' with 16 column(s) and 1 row(s)
# 	'364:J/MNRAS/523/1297/stars' with 7 column(s) and 1 row(s)
# 	'365:J/MNRAS/529/1802/targets' with 21 column(s) and 1 row(s)
# 	'366:J/AN/336/590/varsum' with 11 column(s) and 1 row(s)
# 	'367:J/AcA/64/359/table1' with 15 column(s) and 1 row(s)
# 	'368:J/other/PASA/38.58/galreg' with 33 column(s) and 1 row(s)
# 	'369:J/other/PASA/38.58/gaussreg' with 35 column(s) and 1 row(s)
# 	'370:J/other/JDSO/15.21/hpms3' with 26 column(s) and 1 row(s)

# %% [markdown]
# # Cross-Matching catalogs

# %% [markdown]
# Define a SkyCoord object (See _`Notebook #10: Astropy`_) with the average coordinates of the cluster which may be looked up on Simbad.
#
# ### What is Simbad?
# The Simbad astronomical database is a service also provided by Centre de données astronomiques de Strasbourg (CDS). Simbad provides basic data, cross-identifications, bibliography and measurements for astronomical objects outside the solar system. AstroQuery can query Simbad directly as demonstrated here; however this feature will not be covered in this tutorial. Located at [http://simbad.cds.unistra.fr/simbad/](http://simbad.cds.unistra.fr/simbad/)
#
# Documentation for doing queries in Simbad with AstroQuery can be found [here](https://astroquery.readthedocs.io/en/latest/simbad/simbad.html).
#
# In this example, we'll work with the open cluster [__NGC 188__](http://simbad.u-strasbg.fr/simbad/sim-id?Ident=NGC+188)

# %% [markdown]
# ### Side Note: Vizier has a TON of catalogs. If you're ever unsure what catalog code to use (ex: "I/345"), you can look up the code by catalog name from here:
# [https://cdsarc.cds.unistra.fr/viz-bin/cat](https://cdsarc.cds.unistra.fr/viz-bin/cat)

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.coordinates import Angle, Distance

# Simbad provides parallax instead of distance. However, we can convert one into
# the other using AstroPy tools

ngc188_distance = Distance(parallax = Angle(0.5053 * u.mas)) #mas is milli arcseconds

# we can define the center of our cluster with some coordinates
# Right Ascension, Declination, Distance, proper motion (in ra and dec)
ngc188_center_3d = SkyCoord(ra            = 12.11 * u.deg, #deg is degrees
                            dec           = 85.26 * u.deg,
                            distance      = ngc188_distance,
                            pm_ra_cosdec  = -2.3087 * u.mas / u.yr, #yr is year
                            pm_dec        = -0.9565 * u.mas / u.yr)

# We now query the stars in the cluster from the Gaia EDR3 catalogue 
# on VizieR and define a SkyCoord object for them as well:
from astroquery.vizier import Vizier
from astropy.time import Time
import numpy as np

v = Vizier(catalog = "I/350")         #   I/350 is Gaia eDR3 catalogue
v.ROW_LIMIT = -1                      #   Remove the default row limit to get
                                      #   all the stars

# Query all Gaia stars within 0.5 degrees of the cluster center
result = v.query_region(ngc188_center_3d, radius = 0.5 * u.deg)
gaia_table = result[0]

# Remove stars that are too faint
gaia_table = gaia_table[gaia_table['Gmag'] < 19]
# Remove stars that are too far away
gaia_table = gaia_table[gaia_table['Plx'] > 0.25 * u.mas]

# Create a SkyCoord object containing the coordinates of all of the queried stars
ngc188_coords = SkyCoord(
    ra = gaia_table['RA_ICRS'],
    dec = gaia_table['DE_ICRS'],
    distance = Distance(parallax = Angle(gaia_table['Plx'])),
    pm_ra_cosdec = gaia_table['pmRA'],
    pm_dec = gaia_table['pmDE'],
    obstime = Time('J2016'))   #  Gaia EDR3 observations are all in J2016

# Calculate 3D separations
sep3d = ngc188_coords.separation_3d(ngc188_center_3d)

# Calculate velocity space separations (use Pythagorean theorem)
pm_diff = np.sqrt(
    (ngc188_coords.pm_ra_cosdec - ngc188_center_3d.pm_ra_cosdec)**2 +
    (ngc188_coords.pm_dec - ngc188_center_3d.pm_dec)**2)

# Stars that are too far from each other in 3D space (say, further than
# 50 pc) or stars that have very different proper motions (say, more than
# 1.5 mas / yr) do not belong to the cluster
ngc188_members_mask = (sep3d < 50 * u.pc) & (pm_diff < 1.5 * u.mas/u.yr)
ngc188_coords = ngc188_coords[ngc188_members_mask]

# Print total number of identified members
len(ngc188_coords)
# Out:
# 244

# %%
gaia_table.to_pandas().head(10) #convert to dataframe, then show top 10 rows as a preview
# Out:
#      RA_ICRS  e_RA_ICRS    DE_ICRS  e_DE_ICRS              Source     Plx  \
# 0  12.773032     0.0839  84.780342     0.0727  573362294177391616  1.9255
# 1  14.151603     0.1463  84.792813     0.1292  573363054388266752  0.8329
# 2  13.680818     0.0671  84.780311     0.0592  573363153170854656  0.8470
# 3  13.467402     0.2033  84.792946     0.1728  573363226184519168  0.5928
# 4  13.789755     0.0865  84.808442     0.0719  573363324969551360  0.3704
# 5  13.490407     0.1594  84.812733     0.1311  573363359329289344  0.7398
# 6  13.536455     0.0761  84.818896     0.0640  573363359329290240  0.7486
# 7  13.635230     0.0508  84.822504     0.0416  573363397985649408  0.4787
# 8  13.056681     0.0372  84.772843     0.0336  573363501064865792  0.5277
# 9  13.265345     0.0688  84.775627     0.0590  573363565487712512  0.7017
#
#     e_Plx      PM    pmRA  e_pmRA    pmDE  e_pmDE   RUWE           FG  \
# 0  0.0902  14.760  -7.171   0.104  12.901   0.093  0.932  1352.599976
# 1  0.1584   5.527  -3.845   0.187   3.971   0.179  1.003   526.130005
# 2  0.0723   2.385   2.381   0.089  -0.142   0.080  0.951  1699.800049
# 3  0.2119  19.080  18.403   0.255  -5.037   0.225  2.227   823.650024
# 4  0.0929   0.834  -0.657   0.103   0.513   0.101  1.057  1390.199951
# 5  0.1653   7.934  -7.046   0.197   3.647   0.175  1.017   553.210022
# 6  0.0796   8.197   8.177   0.093  -0.576   0.086  0.989  1551.099976
# 7  0.0530   9.978  -8.272   0.060   5.581   0.056  0.995  3250.199951
# 8  0.0411   0.561   0.491   0.044  -0.272   0.042  0.986  4979.500000
# 9  0.0733   7.851   7.748   0.081  -1.267   0.079  0.973  1770.300049
#
#       e_FG       Gmag    e_Gmag          FBP    e_FBP      BPmag   e_BPmag  \
# 0  1.69010  17.859423  0.003071   296.809998   6.3458  19.157347  0.023380
# 1  0.95254  18.884632  0.003385   141.169998   9.2524  19.964169  0.071213
# 2  1.43430  17.611385  0.002904   625.280029  10.4190  18.348354  0.018306
# 3  2.07790  18.398014  0.003885   274.079987   8.0866  19.243853  0.032156
# 4  1.42250  17.829659  0.002971   688.619995   8.5933  18.243595  0.013833
# 5  1.06590  18.830133  0.003459   135.789993   7.2976  20.006413  0.058418
# 6  1.45160  17.710745  0.002937   544.570007   8.9697  18.498404  0.018100
# 7  2.20340  16.907583  0.002852  1591.599976  13.8970  17.333930  0.009882
# 8  2.47890  16.444395  0.002808  2441.600098  10.1670  16.869339  0.005313
# 9  1.58900  17.567255  0.002923   632.250000  10.7820  18.336319  0.018724
#
#            FRP    e_FRP      RPmag   e_RPmag     BP-RP  RVDR2  e_RVDR2  \
# 0  1620.199951   8.9171  16.723950  0.007070  2.433397    NaN      NaN
# 1   578.700012   6.9217  17.841770  0.013525  2.122398    NaN      NaN
# 2  1521.900024  10.9130  16.791931  0.008654  1.556423    NaN      NaN
# 3  1024.599976  11.2040  17.221500  0.012459  2.022352    NaN      NaN
# 4   971.200012   8.4709  17.279621  0.010196  0.963974    NaN      NaN
# 5   610.770020   7.5784  17.783200  0.013992  2.223213    NaN      NaN
# 6  1440.800049  10.9140  16.851350  0.009051  1.647053    NaN      NaN
# 7  2389.399902   9.4465  16.302187  0.005719  1.031742    NaN      NaN
# 8  3613.600098   9.2405  15.853040  0.004690  1.016299    NaN      NaN
# 9  1580.400024   8.8261  16.750996  0.007145  1.585323    NaN      NaN
#
#    Tefftemp  loggtemp                 PS1  SDSSDR13  SkyMapper2      URAT1  \
# 0       NaN       NaN  209730127729647200      <NA>        <NA>  874001252
# 1       NaN       NaN  209750141513952192      <NA>        <NA>  874001376
# 2       NaN       NaN  209730136803707200      <NA>        <NA>  874001328
# 3       NaN       NaN  209750134679902528      <NA>        <NA>  874001316
# 4       NaN       NaN  209770137894530944      <NA>        <NA>  875001410
# 5       NaN       NaN  209770134901196096      <NA>        <NA>  875001382
# 6       NaN       NaN  209780135359553504      <NA>        <NA>  875001386
# 7       NaN       NaN  209780136349877824      <NA>        <NA>  875001396
# 8       NaN       NaN  209720130565318240      <NA>        <NA>  874001277
# 9       NaN       NaN  209730132649831552      <NA>        <NA>  874001293
#
#     GmagCorr  e_GmagCorr       FGCorr    RAJ2000    DEJ2000
# 0  17.859423    0.003071  1352.599976  12.773382  84.780284
# 1  18.873680    0.003373   531.460022  14.151791  84.792796
# 2  17.611385    0.002904  1699.800049  13.680702  84.780311
# 3  18.388815    0.003869   830.650024  13.466501  84.792969
# 4  17.829659    0.002971  1390.199951  13.789788  84.808440
# 5  18.817390    0.003445   559.750000  13.490753  84.812717
# 6  17.710745    0.002937  1551.099976  13.536053  84.818899
# 7  16.907583    0.002852  3250.199951  13.635637  84.822479
# 8  16.444395    0.002808  4979.500000  13.056657  84.772844
# 9  17.567255    0.002923  1770.300049  13.264967  84.775632

# %% [markdown]
# ### Now load cluster stars from the 2MASS catalogue.
# We are not going to verify membership here because we will eventually cross-match them onto Gaia stars and non-members will not find matches and disappear on their own.

# %%
v = Vizier(catalog = "II/246", columns=['*', 'Date'])       # Include date of observation
v.ROW_LIMIT = -1

# similar to the step above, we're going to query the region around our cluster center
# but this time using the 2MASS catalog ("II/246")

result = v.query_region(ngc188_center_3d, radius = 0.5 * u.deg)
tmass_table = result[0]
len(tmass_table)
# Out:
# 5014

# %% [markdown]
# ### Now to Cross-match
# Define a Time object for the date when 2MASS observations were taken:

# %%
print(np.unique(tmass_table['Date']))
print(' ')
tmass_epoch = Time(np.unique(tmass_table['Date']))
print(tmass_epoch)
print(tmass_epoch.jyear)
print(tmass_epoch.jd)
# Out:
#    Date
# ----------
# 1999-10-19
#
# ['1999-10-19 00:00:00.000']
# [1999.79603012]
# [2451470.5]

# %% [markdown]
# Define a SkyCoord object for 2MASS stars (we only need RA and DEC):

# %%
tmass_coords = SkyCoord(tmass_table['RAJ2000'], tmass_table['DEJ2000'])

# %% [markdown]
# Advance Gaia coordinates to the 2MASS observation date so that we could compare the two together:
#
# To read more about accounting for space motion, check out the [__Astropy documentation__](https://docs.astropy.org/en/stable/coordinates/apply_space_motion.html)

# %%
ngc188_coords_1999 = ngc188_coords.apply_space_motion(tmass_epoch)

# %% [markdown]
# Run the cross-match:
#
# To read more about matching catalogs from coordinates, check out this [__Astropy documentation__](https://docs.astropy.org/en/latest/api/astropy.coordinates.SkyCoord.html#astropy.coordinates.SkyCoord.match_to_catalog_sky)

# %%
idx_gaia, sep2d_gaia, sep3d = ngc188_coords_1999.match_to_catalog_sky(tmass_coords)

# %% [markdown]
# Plot a histogram of separations:

# %%
import matplotlib.pyplot as plt

plt.hist(np.log10(sep2d_gaia.arcsec), bins = 50);
plt.xlabel('log Separation [arcsec]')
plt.show()

# %% [markdown]
# Get apparent J and G magnitudes and make a color-magnitude diagram

# %%
#Let's plot our results over the previous GAIA query


Jmag = tmass_table['Jmag'][idx_gaia]          # Use the cross-match indices
Gmag = gaia_table[ngc188_members_mask]['Gmag']
#convert to absolute magnitude
# M = m - 5log10(d) + 5
# distance from parallax (in mas) is d = 1000 / parallax
MGmag = Gmag - 5*np.log10(1000/gaia_table[ngc188_members_mask]['Plx']) + 5

tmass_bp_rp = gaia_table[ngc188_members_mask]['BPmag'] - gaia_table[ngc188_members_mask]['RPmag']
plt.hist2d(bp_rp, mg, bins=300, cmin=10, norm=colors.PowerNorm(0.5), zorder=0.5)
plt.plot(tmass_bp_rp, MGmag, 'r.',markersize=2)
plt.xlim(-1,6)
plt.ylim(-3,20)
plt.gca().invert_yaxis()

plt.xlabel('G - J')
plt.ylabel('G')
plt.show()
