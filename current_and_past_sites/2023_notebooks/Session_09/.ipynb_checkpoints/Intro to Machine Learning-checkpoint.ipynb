# %%
import pandas as pd

data = pd.read_csv('https://www.sidc.be/SILSO/INFO/sndtotcsv.php', sep=';',
                 names=['Year','Month','Day','Decimal Date','Daily Sunspot Number',
                       'Standard Deviation','Number of Observations','Definitive/provisional indicator'])
data.head(1)
# Out:
#    Year  Month  Day  Decimal Date  Daily Sunspot Number  Standard Deviation  \
# 0  1818      1    1      1818.001                    -1                -1.0
#
#    Number of Observations  Definitive/provisional indicator
# 0                       0                                 1

# %%
import matplotlib.pyplot as plt
df = data.loc[data['Daily Sunspot Number']>0].reset_index(drop=True)
plt.scatter(df['Year'],df['Daily Sunspot Number'],s=0.1)
plt.show()

# %%
import pymc3 as pm
import arviz as az

n = int(len(df)*90/100) #90% it's size

x = df['Year'].values#.reshape(n, 1)
y = df['Daily Sunspot Number'].values#.reshape(n, 1)

prop_train = 0.7
n_train = round(prop_train * n)

x_train = x[:n_train]
y_train = y[:n_train]

x_test = x[n_train:]
y_test = y[n_train:]

# Plot.
fig, ax = plt.subplots()
ax.plot(x_train.flatten(), y_train.flatten(), color='red', label='y_train')
ax.plot(x_test.flatten(), y_test.flatten(), color='blue', label='y_test')
ax.axvline(x_train.flatten()[-1], color='grey', linestyle='--', label='train-test-split')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(title='y train-test split ', xlabel='t', ylabel='');
plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12, center=False).mean()
    rolstd = timeseries.rolling(window=12, center=False).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
test_stationarity(df['Daily Sunspot Number'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.186615e+00
# p-value                        7.868420e-13
# #Lags Used                     5.800000e+01
# Number of Observations Used    6.035200e+04
# Critical Value (1%)           -3.430458e+00
# Critical Value (5%)           -2.861588e+00
# Critical Value (10%)          -2.566795e+00
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig, ax = plt.subplots(figsize=(9,5))
plot_acf(df['Daily Sunspot Number'].diff().dropna(), lags=30, ax=ax)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
fig, ax = plt.subplots(figsize=(9,5))
plot_pacf(df['Daily Sunspot Number'].diff().dropna(), lags=30, ax=ax)
plt.show()
# Out:
# /Users/daxfeliz/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from math import sqrt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
import warnings
warnings.filterwarnings('ignore')

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(dataset, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))


# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
    # prepare training dataset
    splits = TimeSeriesSplit(n_splits=2,test_size=int(0.2*len(X)))
    rmse_test_values = []
    for train_index, test_index in splits.split(X):
        train = X[train_index]
        history = [x for x in train]
        test = X[test_index]
        predictions = []
        print('Observations: %d' % (len(train) + len(test)))
        print('Training Observations: %d' % (len(train)))
        print('Testing Observations: %d' % (len(test)))
        # make predictions
        predictions = list()
        for t in range(len(test)):
            model = ARIMA(history, order=arima_order)
            model_fit = model.fit()
            yhat = model_fit.forecast()[0]
            predictions.append(yhat)
            history.append(test[t])
            # calculate out of sample error
        rmse_test = sqrt(mean_squared_error(test, predictions))
        rmse_test_values.append(rmse_test)
    return np.mean(rmse_test_values)

# %%
evaluate_models(df['Daily Sunspot Number'],[0,1],[0,1],[0,1])
# Out:
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Observations: 48329
# Training Observations: 36247
# Testing Observations: 12082
# Best ARIMANone RMSE=inf

# %%
#def model_report(data,parameters):
data_list = list(df['Daily Sunspot Number'])
parameters=(1,1,1)
train_size = int(0.8*len(data_list))
train = data_list[:train_size]
test = data_list[train_size:]
history = [j for j in train]
predictions = []
summary = None
for t in test:
    model = ARIMA(history, order=parameters)
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    if summary is None:
        summary = model_fit.summary()
        residuals = pd.DataFrame(model_fit.resid)
    predictions.append(yhat)
    history.append(t)
print(summary)
plt.subplot(2,1,1)
plt.title('residuals plot')
residuals.plot(kind='kde')
rmse = sqrt(mean_squared_error(test, predictions))
plotframe = df.copy()
plotframe['forecast'] = train+predictions
plt.plot(2,1,2)
plotframe.plot()
#plt.plot(3,1,3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 12
#      10 for t in test:
#      11     model = ARIMA(history, order=parameters)
# ---> 12     model_fit = model.fit()
#      13     yhat = model_fit.forecast()[0]
#      14     if summary is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py:390, in ARIMA.fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     387 else:
#     388     method_kwargs.setdefault('disp', 0)
# --> 390     res = super().fit(
#     391         return_params=return_params, low_memory=low_memory,
#     392         cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#     393     if not return_params:
#     394         res.fit_details = res.mlefit
#
# ...

# %%
X = df['Daily Sunspot Number'].values

# 66% train set; 34% test size
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]

print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))

plt.figure(figsize=(10, 6), dpi=75)
plt.plot(train, color = 'green')
plt.plot([None for i in train] + [x for x in test], color = 'red')
plt.title("Splitting data into train and test", fontsize=16)
plt.xlabel('Index')
plt.ylabel('Daily Sunspot Number')
plt.grid()
plt.show()
# Out:
# Observations: 60411
# Training Observations: 39871
# Testing Observations: 20540

# %%
from sklearn.model_selection import TimeSeriesSplit

# three splits for the outer loop
splits = TimeSeriesSplit(n_splits=3)
fig = plt.figure(1, figsize = (12, 6*3), dpi = 75)
fig.suptitle("Splitting data into 3 outer loops", fontsize=16)
index = 1

for train_index, test_index in splits.split(X):
    train = X[train_index]
    test = X[test_index]
    
    print('Observations: %d' % (len(train) + len(test)))
    print('Training Observations: %d' % (len(train)))
    print('Testing Observations: %d' % (len(test)))
    
    ax = fig.add_subplot(310 + index)
    ax.set_xlabel('Index')
    ax.set_ylabel('Daily Sunspot Number')
    ax.set_title('Split - {}'.format(str(index)), fontsize=14)
    ax.plot(train, color = 'green')
    ax.grid()
    ax.plot([None for i in train] + [x for x in test], color = 'red')
    index += 1
    
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# Observations: 30207
# Training Observations: 15105
# Testing Observations: 15102
# Observations: 45309
# Training Observations: 30207
# Testing Observations: 15102
# Observations: 60411
# Training Observations: 45309
# Testing Observations: 15102

# %%
import statsmodels.api as sm
from scipy import stats

#Present the correlation in the time series data. 
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Daily Sunspot Number'].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Daily Sunspot Number'], lags=40, ax=ax2)
plt.show()
# Out:
# /Users/daxfeliz/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#Fit the data to ARMA and present the parameters.
# arma_mod20 = sm.tsa.ARIMA(df['Daily Sunspot Number'], (2,0)).fit()
from statsmodels.tsa.arima.model import ARIMA
arma_mod20 = ARIMA(df['Daily Sunspot Number'], order=(2, 0, 0)).fit()
print(arma_mod20.params)
print(' ')
#Creat another ARMA model with differnt length.
arma_mod30 = ARIMA(df['Daily Sunspot Number'], order=(3, 0, 0)).fit()
print(arma_mod30.params)
print(' ')
# Out:
# const      97.882720
# ar.L1       0.895518
# ar.L2       0.053362
# sigma2    578.631208
# dtype: float64
#
# const      97.882720
# ar.L1       0.897052
# ar.L2       0.079068
# ar.L3      -0.028701
# sigma2    578.143279
# dtype: float64

# %%
#Comapre the likelihood between them.
print(arma_mod20.aic, arma_mod20.bic, arma_mod20.hqic)
print(arma_mod30.aic, arma_mod30.bic, arma_mod30.hqic)
# Out:
# 555703.126918051 555739.1626239972 555714.3165695909
# 555655.3286375562 555700.3732699889 555669.3157019811

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111)
ax = arma_mod30.resid.plot(ax=ax)
plt.show()

resid = arma_mod30.resid
stats.normaltest(resid)
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111)
from statsmodels.graphics.api import qqplot
fig = qqplot(resid, line="q", ax=ax, fit=True)
plt.show()

# %%
fig = plt.figure(figsize=(6, 6))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=40, ax=ax2)
plt.show()
# Out:
# /Users/daxfeliz/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
r, q, p = sm.tsa.acf(resid.values.squeeze(), fft=True, qstat=True)
data = np.c_[np.arange(1, len(q)+1), r[1:], q, p]

table = pd.DataFrame(data, columns=["lag", "AC", "Q", "Prob(>Q)"])
print(table.set_index("lag"))

start_ind = int(df.loc[df['Decimal Date']==1990.001].index.values)
end_ind = int(df.loc[df['Decimal Date']==2012.001].index.values)
predict_sunspots = arma_mod30.predict(start_ind, end_ind, dynamic=True)
print(predict_sunspots)
# Out:
#             AC            Q       Prob(>Q)
# lag
# 1.0  -0.000261     0.004122   9.488065e-01
# 2.0   0.000341     0.011141   9.944452e-01
# 3.0   0.010244     6.350575   9.574544e-02
# 4.0   0.003624     7.143839   1.284794e-01
# 5.0  -0.020020    31.360323   7.951169e-06
# 6.0  -0.030508    87.596126   9.559775e-17
# 7.0  -0.039328   181.047436   1.170589e-35
# 8.0  -0.037924   267.945958   2.684947e-53
# 9.0  -0.045040   390.518103   1.443380e-78
# 10.0 -0.035992   468.792475   2.041934e-94
# 11.0 -0.022294   498.825048  5.710413e-100
# 12.0 -0.018979   520.589602  9.160960e-104
# 13.0 -0.016202   536.451290  2.615641e-106
# 14.0  0.001741   536.634397  1.569148e-105
# 15.0 -0.002790   537.104834  7.876323e-105
# 16.0 -0.003038   537.662651  3.659162e-104
# 17.0 -0.001981   537.899747  1.923670e-103
# 18.0  0.001390   538.016482  1.039610e-102
# 19.0  0.011952   546.649287  8.819428e-104
# 20.0  0.017879   565.967673  4.185603e-107
# 21.0  0.029627   619.013644  1.597420e-117
# ...

# %%
def mean_forecast_err(y, yhat):
    return y.sub(yhat).mean()
mean_forecast_err(df['Daily Sunspot Number'], predict_sunspots)
# Out:
# -2.6671944435564616
