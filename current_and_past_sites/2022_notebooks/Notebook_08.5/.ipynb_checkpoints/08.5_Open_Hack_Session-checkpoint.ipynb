# %% [markdown]
# # Session 8.5 - <span style="color:red">Open Hack Session</span>
#
# > Copyright © Dax Feliz. All rights reserved.
# > This work is licensed under CC BY-NC-ND 4.0.
# > Personal, non-commercial viewing only.
# > Educational or instructional use is not permitted under the default license.
# > Instructors or institutions interested in licensing this material should contact me for permission and terms.
# >
# > Full license:
# > https://github.com/daxfeliz/cunybridgebootcamp/blob/main/LICENSE

# %% [markdown]
# ## Today's Agenda
# - Pitch your projects
# - You can get help with programming questions
# - etc.
#
# Fill out the Google Doc using the following link: [https://docs.google.com/document/d/1FmIJNO8n92sc-oF39BJVXXtZtadgNYm4BAen83hJ3Vg/edit)
