# %% [markdown]
# # First Session, Notebook # 1: Introduction and Computer Set Up
#
# ## Today's agenda:
# 0. __Workshop Overview__:
#     * __When__: August 17th, 2-5pm <!---*insert day* from *insert time range*--->
#     * __Where__: CUNY Graduate Center <!---*insert room number--->
#     * __What__: Most days we'll be working on a new topic (or topics) in coding
#     * __Want__ to lead a session for a topic? Some Days there will be small hack sessions for people to discuss problems they're working on.
#     * __Online Resources__:
#     __https://daxfeliz.github.io/cunybridgebootcamp/__
#     * __Program Schedule__: [__Bootcamp Schedule__](https://docs.google.com/document/d/1NmAingHU1cxXDbTskqAUtdqGvl1vm3xsJeNqb4MUMq4/edit?usp=sharing)
# </br>
# &nbsp;
#
# 1. __This session__:
#     * Introduction to the class, Anaconda installation, Bash environment set up and setting up Git & Github access  and to some __useful__ programs and services applicable to research.
# </br>
# &nbsp;
#
# 2. __Next session__:
#
#     * GitHub practice! __Make sure you bring your laptop to this session and future sessions__.
#
#
# > **Copyright © 2026 Dax Feliz. All Rights Reserved.**
# > This material is licensed for personal, non-commercial viewing and reference only.
# > The following uses are **not permitted** without explicit written permission and
# > payment of applicable licensing fees:
# > - Teaching, instruction, workshops, or courses (institutional or otherwise)
# > - Redistribution or reposting in any form
# > - Derivative works
# > - Commercial or institutional use
# > Institutions or instructors interested in licensing this material should contact
# > Dax Feliz for terms and pricing.
# > Full license: https://github.com/daxfeliz/cunybridgebootcamp/blob/main/LICENSE

# %%
from IPython.display import Image, display
# display(Image(filename='./images/CUNY_Bridge_Intro.png', embed=True)) #who am I slide
display(Image(filename='./images/CUNY_Bridge_Intro_(1).png', embed=True))
display(Image(filename='./images/CUNY_Bridge_Intro_(2).png', embed=True))

# %% [markdown]
# # Step 0: Getting used to using the Command Terminal
# In Linux/Mac OSX systems, there will be an application called a Command Terminal (or sometimes just called Terminal) that we can use to navigate our computers with or run code from. To find the Terminal:
#
# * In Linux computers, you can search for Terminal in the Application Finder menu.
# * In Mac OSX computers, you can use the Finder tool to look in your Applications/utilities folder to find the Terminal application.
#
# I'd recommend pinning this application to your tool bar for easy access.

# %% [markdown]
# # Step 1: Installing Anaconda!
#
# ## Quick note about Licensing changes to conda:
# Since 2024, Anaconda clarified its Terms of Service so that organizations with $\ge$ 200 employees or contractors must buy a paid Business license to use Anaconda’s repositories (the default “defaults” channel many conda installs use); this threshold applies to companies, governments, and non-profits, with separate carve-outs for accredited educational use (like universities) in course curricula. Practically, if your conda/Miniconda setup downloads from Anaconda’s repos inside a large organization, you’re expected to pay—or switch to a community source like conda-forge via Miniforge. More details about the changes in licensing can be found  [__here__](https://www.datacamp.com/blog/navigating-anaconda-licensing).
#
# To combat this, institutions like Flatiron Institute Center for Computational Astrophysics (a non-profit organization) has a firewall blocking downloads from conda's default channel. You can use default conda as a package manager but you'll have to download packages from conda-forge if using conda while at CCA. Something to think about.
#
# ## To avoid issues in the future, we're going to use miniforge for bootcamp instead of conda. Should you want to use conda anyways now or in the future, I will leave instructions below. If you change your mind at a later time, I can help!

# %% [markdown]
# ## Installing miniforge
#
# ### Miniforge is a mini-installer of anaconda that defaults to installing packages from the community-based conda-forge channel (which is free!) and organization independent: university vs non-profit, doesn't matter!
#
# ## Step 1a: Locate the "Terminal" application in your macbook. Can be found with Mac shortcut for spotlight (⌘ + space), then typing in "Terminal". (I'd recommend pinning this application to your dock)
#
# ## Step 1b: Get the installer (about 60MB)
# ```
# curl -L -O "https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-$(uname)-$(uname -m).sh"
# ```
#
# ## Step 1c: Run the installer
# ```
# bash Miniforge3-$(uname)-$(uname -m).sh
# ```
#
# ## follow prompts
# - hit enter until prompted with yes/no to accept/reject licensing terms
# - set where you wanna set base installation for where to place miniforge3
# - default to ${HOME}, press enter
# - after installation is finished, you'll be prompted with yes/no to have your shell environment automatically initialize conda. We want this. Enter yes.
#
# ## You should see a message that looks something like:
# ```
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Running `shell init`, which:
#  - modifies RC file: "/Users/YOUR_USER_NAME/.zshrc"
#  - generates config for root prefix: "/Users/YOUR_USER_NAME/miniforge3"
#  - sets mamba executable to: "/Users/YOUR_USER_NAME/miniforge3/bin/mamba"
# The following has been added in your "/Users/YOUR_USER_NAME/.zshrc" file
#
# # >>> mamba initialize >>>
# # !! Contents within this block are managed by 'mamba shell init' !!
# export MAMBA_EXE='/Users/YOUR_USER_NAME/miniforge3/bin/mamba';
# export MAMBA_ROOT_PREFIX='/Users/YOUR_USER_NAME/miniforge3';
# __mamba_setup="$("$MAMBA_EXE" shell hook --shell zsh --root-prefix "$MAMBA_ROOT_PREFIX" 2> /dev/null)"
# if [ $? -eq 0 ]; then
#     eval "$__mamba_setup"
# else
#     alias mamba="$MAMBA_EXE"  # Fallback on help from mamba activate
# fi
# unset __mamba_setup
# # <<< mamba initialize <<<
#
# Thank you for installing Miniforge3!
# ```
#
# ## Step 1d: conda should now be installed! For changes to take effect, close this terminal and open a new one!
#
# ## Step 1e: Update everything next! (May take a few minutes)
# ```
# conda update --all
# ```
# - Eventually you'll be prompted with y/n to install recommended packages. Enter y.
#
# ## Step 1f: Install "git" and "notebook"
# ```
# conda install git
# conda install notebook
# ```

# %% [markdown]
# ### Installing conda (OPTIONAL, See above "Quick note about Licensing changes to conda")

# %% [markdown]
# Anaconda is a great way to handle your modules and their dependencies.
#
# You have the option to use install  __Python 3.13__.
#
# - [Download Anaconda](https://www.anaconda.com/download/success) (larger installation file, may take a while on CUNY GC Wifi)

# %% [markdown]
# # Other package managers worth exploring as alternatives to Anaconda:
# ## - [uv](https://docs.astral.sh/uv/getting-started/installation/)
#     - A single tool to replace pip, pip-tools, pipx, poetry, pyenv, twine, virtualenv, and more.
#     - 10-100x faster than pip.
# ## - [Pixi](https://pixi.sh/latest/)
#     - Good for reproducibility of environments and packages
#     - Supports Multiple languages

# %% [markdown]
# # Step 2: Some quick bash basics!

# %% [markdown]
# ### Basic bash commands
# * `pwd` - Returns the pathway that you are currently in (i.e. how to list where you are currently located in your machine.)
# * `cd [path]` - Change the path you are in
# * `ls [file name]` - list all files in the current location with a input file name
# * `vim [file name]` - will open a text editor for a input file name
#
# ### vim basics:
# * `vim [file name]` will activate a text editor in your terminal
# * once the text editor is activated, you will see the contents of the file
# * to make edits, press `"i"` once to enter "insert" mode. Then you can type in changes to the file.
# * Note: cursor clicks don't work in vim, you'll need to use the arrow keys to get around. You can scroll though!
# * Once your edits are complete, press `"esc"` once to exit "insert mode".
# * To save your changes, type in `":w"`
# * To quit the vim text editor, type in `":q"`. Note unsaved changes will prevent this.
# * To force quit without saving changes, type in `":q!"`.
# * To save your changes and exit the vim text editor in one step, type in `":wq"`
# * To overwrite the file and force quit to exit the vim text editor in one step,, type in `":wq!"`

# %% [markdown]
# # Step 3: Using Vim for editing our computer environments

# %% [markdown]
# After the Anaconda installation is complete, you should see that your "_PATH_" was modified in your "__~/.bashrc__" (Linux) or "__~/bash_profile__" file. If your Mac has Catalina (10.15) / Big Sur (11) / Monterey (12) / Ventura (13) / Sonoma (14) / Sequoia (15) as its operating system, it uses a "zshell" instead of a "bash shell". Instead of a "__~/.bashrc__" file, you should have a "__~/.zshrc__" file.
#
# To check if you have a __~/.bashrc__ file (or "__~/.zshrc__" file), enter this command in your terminal:
# ```bash
# ls ~/.bashrc
# ```
#
# or
#
# ```bash
# ls ~/.zshrc
# ```
#
# If you have NEITHER a __~/.bashrc__ file (or "__~/.zshrc__" file), you can create one like so:
#
# If Mac OS $\lt$ 10.15:
# ```bash
# vi ~/.bashrc
# ```
#
# or
#
# If Mac OS $\ge$ 10.15:
# ```bash
# vi ~/.zshrc
# ```
#
# which will open a blank file. Enter into insert mode (type "i"), then paste in:
#
# ```bash
# PATH=$PATH:~/bin
# ```
#
#
# For Mac OSX Users, another step is required:
#
# For users with Mac OS $\lt$ 10.15, you'll have to edit your "__~/.bash_profile__" file to include the line:
#
# ```bash
# source ~/.bashrc
# ```
#
# or if you have Mac OS $\ge$ 10.15, you'll have to edit your "__~/.zprofile__" file to include the line:
# ```bash
# source ~/.zshrc
# ```
# #### So then, in your __~/.bashrc__ file (or "__~/.zshrc__" file), you should see the following line somewhere in the file's contents:
#
#
# If using miniforge:
# ```bash
# PATH="/Users/YOUR_USER_NAME/miniforge3/bin:$PATH
# ```
#
# If using anaconda:
# ```bash
# export PATH="~/anaconda3/bin:$PATH"
# ```

# %% [markdown]
# ### Updated conda modules
#
# Whenever you want to update your Python modules to the latest versions, you can just run these commands from the terminal:
#
# ```bash
# conda update conda
# ```
#
# ### Installing new Modules
#
# If you want to install a new module that is hosted by Anaconda, you can type:
#
# ```bash
# conda install <name of package>
# ```
#
# or use the Package Installer for Python (pip) software:
# ```bash
# pip install <name of package>
# ```
#
# And the package should be installed with _all_ the necessary dependencies.

# %% [markdown]
# # Installing Modules we'll need for this bootcamp:
#
#
# Here is a one-line piece of code to enter into your terminal to install the relevant modules we'll need:
#
# ```
# conda install git numpy scipy matplotlib pandas seaborn astropy astroquery pillow imageio pymc arviz corner pillow imageio scikit-learn ; pip install celerite2
# ```
#
# Whenever prompted for ```[y/n]``` or ```[Y/n]``` or ```[yes/no]```, select y, Y, or Yes to install at every prompt.

# %% [markdown]
# # Step 4: Setting up Git and GitHub

# %% [markdown]
# Nowadays it is really important to keep track of every change that make to a code, especially if you're
# part of a large organizations.
#
# Git is a tool for _version control_ of your code, i.e. you can keep track of
# - any changes made to your code
# - any issues with your code
# - you can consult other team members about implementing a new feature
# - you can restore a code to a previous version
# - etc.
#
# In a nutshell, __you should be using Git__.
#
# _Git_ might already come pre-installed with _Anaconda_ (it does not if you use miniforge!). You can test whether it is installed on your machine by typing:
#
# ```bash
# which git
# ```
#
# And you shoud see the path to the _git_ executable.
#
# If it is not installed or if you see a pathname which differs from something like `/Users/YOUR_USER_NAME/miniforge3/bin/git` OR `/Users/YOUR_USER_NAME/opt/anaconda3/bin/git` , you can install it with the command:
# ```bash
# conda install git
# ```
# Otherwise, you can install it from [here](https://git-scm.com/)

# %% [markdown]
# ## Creating your Github Account:
#
# "Github" is a website for you to manage your repositories and collaborate with other people.
#
# _Github_ offers a __Student Pack__ for free ([https://education.github.com/](https://education.github.com/)).
# You have to use your __@login.cuny.edu__ email address to get it AND/OR use a picture of your student ID.
#
# You'll likely not have CUNY student emails (or IDs) just yet so for now, you can sign up for a regular Github account at https://github.com/signup
#
# With a GitHub account, you can create __public__ and __private__ repositories where you can store code or data.

# %% [markdown]
# # Quick GitHub basics!

# %% [markdown]
# ## Github Concepts
#
# #### Git Commands
# Before you begin, make sure _git_ is working correctly (detailed instructions and explanations [here](https://git-scm.com/book/en/v2/Getting-Started-First-Time-Git-Setup)):
#
#
# You can view all of your settings and where they are coming from using:
# ```bash
# git config --list --show-origin
# ```
#
# To set your Indentity:
# ```bash
# git config --global user.name "John Doe"
# git config --global user.email johndoe@example.com
# ```

# %% [markdown]
# # Step 5: Getting Bootcamp resources.
#
# ## To clone the local repository of this bootcamp, type the following command:
# ### first, we'll change directories to our Desktops:
# ```bash
# cd ~/Desktop
# ```
# ### then, we type:
# ```bash
# git clone https://github.com/daxfeliz/CUNY_Bridge_BootCamp.git
# ```
# (This may take a few minutes)
#
# This will __clone__ the GitHub Repository into a directory on your __Desktop__, which contains the resources we'll be using throughout this bootcamp

# %% [markdown]
# ### Important Git commands (we'll come back to this)
#
# - __git clone__: Clone an existing repository
# - __git init__: Initialize a git repository. This will create a new repository in your computer
# - __git pull__: This will pull any changes that have been made, and merged them to you current version of the repository
# - __git push__: It will push all your changes to the repository
# - __git commit -m "I changed this and that"__: Commit and comment on any new changes made to the files

# %% [markdown]
# ## Slack
#
# We will be using Slack to communicate ideas, resources, changes to the schedule, etc. Make sure to download the app, since it makes it easier to know what's happening.
#
# * __Slack Channel__: [CUNY Bridge Programming Bootcamp](https://join.slack.com/t/cunybridgepro-as48674/shared_invite/zt-1cfvx2qdy-EymvUOdQnUEMirdPbNr9fA)
# * __Team Name__: cunybridgebootcamp
# * __Email address__: You can use any email address. You just need to sign up to get an invite.
# * __Slack App__: You can download the Slack app for your computer/phone [here](https://slack.com/downloads).
#
# Slack is a platform to facilitate communication among team members.
# * One can easily share documents!
# * Talk to each member of the group
# * _Replaces_ the need of emails
# * And more!
#
#
# ![my_image](./images/Slack_01.png)
