# %% [markdown]
# # <span style="color:red">Open Hack Session</span>

# %% [markdown]
# ## Today's Agenda
# - Pitch your projects
# - You can get help with programming questions
# - etc.
#
# Fill out the Google Doc using the following link: [https://docs.google.com/document/d/1UYKzubjSIA2pcq8qzkzTO62GEqvrCovPzgR7V74cNGk/edit?usp=sharing]
